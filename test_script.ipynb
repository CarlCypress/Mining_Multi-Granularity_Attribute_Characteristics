# %%
import readSql
import pandas as pd

# %%
tool = readSql.sql_tool('Yago_pure')

# %%
tool.get_table('yagoTaxonomy')
# Out:
#                                                    subject       predicates  \
# 0                 <wikicat_Chinese_emigrants_to_Argentina>  rdfs:subClassOf
# 1        <wikicat_Rural_Districts_of_South_Khorasan_Pro...  rdfs:subClassOf
# 2                  <wikicat_Towns_in_Cook_County,_Georgia>  rdfs:subClassOf
# 3                               <wikicat_Male_high_divers>  rdfs:subClassOf
# 4             <wikicat_Pubs_in_the_West_Midlands_(county)>  rdfs:subClassOf
# ...                                                    ...              ...
# 1754635               <wikicat_Mining_disasters_in_Guinea>  rdfs:subClassOf
# 1754636   <wikicat_Museums_in_Atlantic_County,_New_Jersey>  rdfs:subClassOf
# 1754637   <wikicat_Rwandan_emigrants_to_the_United_States>  rdfs:subClassOf
# 1754638              <wikicat_Islands_of_the_Adriatic_Sea>  rdfs:subClassOf
# 1754639  <wikicat_Railway_stations_on_the_Arnhem____Nij...  rdfs:subClassOf
#
# ...
